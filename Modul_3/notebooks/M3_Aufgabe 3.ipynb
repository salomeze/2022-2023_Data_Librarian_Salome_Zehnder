# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline
sns.set()

# %%
df = pd.read_csv('/home/salome/Schreibtisch/shell-lesson/2022-2023_Data_Librarian_Salome_Zehnder/Modul_3/data/Library_Usage.csv')

# %% [markdown]
# ## Aufgabe 3.1

# %%
df.columns
# Out:
# Index(['Patron Type Code', 'Patron Type Definition', 'Total Checkouts',
#        'Total Renewals', 'Age Range', 'Home Library Code',
#        'Home Library Definition', 'Circulation Active Month',
#        'Circulation Active Year', 'Notice Preference Code',
#        'Notice Preference Definition', 'Provided Email Address',
#        'Year Patron Registered', 'Within San Francisco County'],
#       dtype='object')

# %%
#Erstelle eine Häufigkeitsverteilung für die Variable 'Year Patron Registered'. 
df['Year Patron Registered'].value_counts().sort_values()
# Out:
# 2004     4738
# 2005     5069
# 2006     5579
# 2007     6900
# 2008    10760
# 2010    11884
# 2009    12098
# 2011    13285
# 2012    13908
# 2013    14245
# 2014    17028
# 2015    21105
# 2016    22551
# 2018    30262
# 2017    30419
# 2021    32568
# 2020    32999
# 2003    42903
# 2022    52377
# 2019    56437
# Name: Year Patron Registered, dtype: int64

# %%
df['Year Patron Registered'].value_counts().sort_values().sum()
# Out:
# 437115

# %%
#Wieviel Prozent der Kunden wurden 2013 im System registriert? 
df['Year Patron Registered'].value_counts(normalize=True).sort_values()
# Out:
# 2004    0.010839
# 2005    0.011596
# 2006    0.012763
# 2007    0.015785
# 2008    0.024616
# 2010    0.027187
# 2009    0.027677
# 2011    0.030392
# 2012    0.031818
# 2013    0.032589
# 2014    0.038955
# 2015    0.048282
# 2016    0.051591
# 2018    0.069231
# 2017    0.069590
# 2021    0.074507
# 2020    0.075493
# 2003    0.098150
# 2022    0.119824
# 2019    0.129112
# Name: Year Patron Registered, dtype: float64

# %%
#Wie viele in den kommenden Jahren? Was fällt Dir auf?
sns.catplot(y='Year Patron Registered',
            data=df, kind='count', color="purple")

# %% [markdown]
# ## Aufgabe 3.2

# %%
#Schau Dir den Mittelwert und den Median der Variable Total Checkouts an. Warum sind die beiden Werte so unterschiedlich?
#es gibt einzelne Dokumente die extrem viel öfters ausgeliehen wurde als andere.

# %%
df['Total Checkouts'].mean()
# Out:
# 161.08505542019836

# %%
df['Total Checkouts'].median()
# Out:
# 7.0

# %%
#Was ziehst Du daraus für Schlüsse für weitere statistische Analysen und Reports?
#Man sollte die Quartile miteinbeziehen.

# %% [markdown]
# ## Seaborn-Tutorial

# %%
sns.relplot(x='Total Checkouts', y='Total Renewals', data=df)

# %%
sns.relplot(x='Total Checkouts', y='Total Renewals', data=df,
            height=5, aspect=3)

# %%
sns.relplot(x='Total Checkouts', y='Total Renewals', 
                hue='Provided Email Address', style='Within San Francisco County', 
                size='Year Patron Registered', data=df)

# %%
sns.relplot(x='Total Checkouts', y='Total Renewals', 
                hue='Provided Email Address', style='Within San Francisco County', 
                size='Year Patron Registered', data=df,
           height=8, aspect=3)

# %%
sns.relplot(x='Total Checkouts', y='Total Renewals', 
            size='Year Patron Registered',
            row='Provided Email Address', col='Within San Francisco County', data=df,
           height=6, aspect=3)

# %%
sns.relplot(x='Total Checkouts', y='Total Renewals', 
            hue='Provided Email Address', 
            col='Within San Francisco County',
            palette=sns.color_palette('Accent', 2), 
            data=df)

# %%
sns.catplot(y='Year Patron Registered',
            data=df, kind='count', color="purple")

# %%
sns.catplot(y='Age Range', hue='Provided Email Address', 
            data=df, kind='count')
