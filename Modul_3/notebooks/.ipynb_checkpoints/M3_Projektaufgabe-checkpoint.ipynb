# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline
sns.set()

# %%
df = pd.read_csv('/home/salome/Schreibtisch/shell-lesson/2022-2023_Data_Librarian_Salome_Zehnder/Modul_3/data/Library_Usage.csv')

# %%
df.columns
# Out:
# Index(['Patron Type Code', 'Patron Type Definition', 'Total Checkouts',
#        'Total Renewals', 'Age Range', 'Home Library Code',
#        'Home Library Definition', 'Circulation Active Month',
#        'Circulation Active Year', 'Notice Preference Code',
#        'Notice Preference Definition', 'Provided Email Address',
#        'Year Patron Registered', 'Within San Francisco County'],
#       dtype='object')

# %%
df
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 0                      1               Juvenile                0
# 1                      2                   Teen                0
# 2                      0                  Adult                0
# 3                      2                   Teen                0
# 4                      2                   Teen                0
# ...                  ...                    ...              ...
# 437110                 0                  Adult               14
# 437111                 0                  Adult                2
# 437112                 3                 Senior                5
# 437113                 3                 Senior                4
# 437114                 3                 Senior                3
#
#         Total Renewals          Age Range Home Library Code  \
# 0                    0       0 to 9 years                r3
# 1                    0     10 to 19 years                 x
# ...

# %% [markdown]
# ## Teilaufgabe 1: Wie viele Ausleihen gab es pro Bibliothek?

# %%
df['Total Checkouts'].sum()
# Out:
# 70412694

# %%
checkouts_library = df[['Home Library Definition','Total Checkouts']]
checkouts_library.sort_values('Home Library Definition')
# Out:
#        Home Library Definition  Total Checkouts
# 125231                    Anza              159
# 244153                    Anza               14
# 316495                    Anza               22
# 316503                    Anza                8
# 244175                    Anza               56
# ...                        ...              ...
# 273156        Western Addition              123
# 385118        Western Addition                0
# 92049         Western Addition             2151
# 92005         Western Addition               43
# 368514        Western Addition                6
#
# [437115 rows x 2 columns]

# %%
#Ausleihen pro Bibliothek Total

checkouts_library.groupby(by='Home Library Definition').sum()
# Out:
#                          Total Checkouts
# Home Library Definition
# Anza                             2166633
# Bayview                           646451
# Bernal                           1712139
# Bookmobile                        245190
# Chinatown                        4444310
# Eureka Valley                    2297427
# Excelsior                        2966965
# Glen Park                        1901287
# Golden Gate                       969174
# Ingleside                        1953411
# Main                            11767324
# Marina                           1468116
# Merced                           2672194
# Mission                          2869094
# Mission Bay                      1220817
# Noe Valley                       1614775
# North Beach                      1605010
# Ocean View                        587723
# Ortega                           4941691
# Park                             1560430
# Parkside                         2172359
# ...

# %%
sns.catplot(y='Home Library Definition',
            data=checkouts_library, kind='count', color="purple")

# %% [markdown]
# ## Teilaufgabe 2: Wie viele Teenager haben sich im Jahr 2009 in der Main-Bibliothek eingeschrieben?

# %%
teen=df.loc[df['Patron Type Definition'] == 'Teen',:]
teen
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 1                      2                   Teen                0
# 3                      2                   Teen                0
# 4                      2                   Teen                0
# 5                      2                   Teen                0
# 6                      2                   Teen                0
# ...                  ...                    ...              ...
# 436895                 2                   Teen                1
# 436903                 2                   Teen               10
# 436954                 2                   Teen               18
# 436961                 2                   Teen                3
# 436979                 2                   Teen                3
#
#         Total Renewals       Age Range Home Library Code  \
# 1                    0  10 to 19 years                 x
# 3                    0  10 to 19 years                 x
# ...

# %%
teen_main = teen.loc[teen['Home Library Definition'] == 'Main',:]
teen_main
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 1                      2                   Teen                0
# 3                      2                   Teen                0
# 5                      2                   Teen                0
# 6                      2                   Teen                0
# 7                      2                   Teen                0
# ...                  ...                    ...              ...
# 436688                 2                   Teen                5
# 436737                 2                   Teen                1
# 436840                 2                   Teen                2
# 436903                 2                   Teen               10
# 436961                 2                   Teen                3
#
#         Total Renewals       Age Range Home Library Code  \
# 1                    0  10 to 19 years                 x
# 3                    0  10 to 19 years                 x
# ...

# %%
teen_main_2009 = teen_main.loc[teen_main['Year Patron Registered'] == 2009]
teen_main_2009
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 63434                  2                   Teen              288
# 64177                  2                   Teen              574
# 68000                  2                   Teen              277
# 86171                  2                   Teen              218
# 93899                  2                   Teen              150
# ...                  ...                    ...              ...
# 436383                 2                   Teen              121
# 436566                 2                   Teen               48
# 436840                 2                   Teen                2
# 436903                 2                   Teen               10
# 436961                 2                   Teen                3
#
#         Total Renewals       Age Range Home Library Code  \
# 63434               51  10 to 19 years                 x
# 64177              581  10 to 19 years                 x
# ...

# %%
teen_main_2009.mean()
# Out:
# /tmp/ipykernel_3573/1510895692.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   teen_main_2009.mean()
# Patron Type Code                  2.000000
# Total Checkouts                 358.786885
# Total Renewals                  104.207650
# Circulation Active Year        2020.377049
# Provided Email Address            0.846995
# Year Patron Registered         2009.000000
# Within San Francisco County       0.967213
# dtype: float64

# %%
sns.relplot(x='Total Checkouts', y='Total Renewals', data=teen_main_2009,
            height=5, aspect=3)
